# %%
import pandas as pd
import chardet 


filename = "E:\\python folder\\records.csv"

# %% [markdown]
# # Importing CSV file using read_csv

# %%
data = pd.read_csv(filename)
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# # To know the encoding of CSV file use python chardet library

# %%
with open(filename, 'rb') as file:
    print(chardet.detect(file.read()))
# Out:
# {'encoding': 'UTF-8-SIG', 'confidence': 1.0, 'language': ''}

# %% [markdown]
# # Using manual method to load csv file

# %%
def load_data(filename):
    with open (filename , encoding = "UTF-8-SIG") as f:
        cols = []
        data = []
        for i , line in enumerate(f.read().splitlines()):
            if i == 0:
                cols = cols + line.split(",")
            else:
                data.append(float(x) for x in line.split(","))
        data = pd.DataFrame(data , columns=cols)
    return data

# %%
load_data(filename)
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  3.0     145.0  233.0  1.0      0.0    150.0    0.0      2.3
# 1    37.0  1.0  2.0     130.0  250.0  0.0      1.0    187.0    0.0      3.5
# 2    41.0  0.0  1.0     130.0  204.0  0.0      0.0    172.0    0.0      1.4
# 3    56.0  1.0  1.0     120.0  236.0  0.0      1.0    178.0    0.0      0.8
# 4    57.0  0.0  0.0     120.0  354.0  0.0      1.0    163.0    1.0      0.6
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 298  57.0  0.0  0.0     140.0  241.0  0.0      1.0    123.0    1.0      0.2
# 299  45.0  1.0  3.0     110.0  264.0  0.0      1.0    132.0    0.0      1.2
# 300  68.0  1.0  0.0     144.0  193.0  1.0      1.0    141.0    0.0      3.4
# 301  57.0  1.0  0.0     130.0  131.0  0.0      1.0    115.0    1.0      1.2
# 302  57.0  0.0  1.0     130.0  236.0  0.0      0.0    174.0    0.0      0.0
#
#      slope   ca  thal  target
# 0      0.0  0.0   1.0     1.0
# 1      0.0  0.0   2.0     1.0
# 2      2.0  0.0   2.0     1.0
# 3      2.0  0.0   2.0     1.0
# 4      2.0  0.0   2.0     1.0
# ..     ...  ...   ...     ...
# 298    1.0  0.0   3.0     0.0
# 299    1.0  0.0   3.0     0.0
# 300    1.0  2.0   3.0     0.0
# 301    1.0  1.0   3.0     0.0
# 302    1.0  1.0   2.0     0.0
#
# [303 rows x 14 columns]
